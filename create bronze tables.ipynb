# %% [markdown]
# **In this notebook, bronze layer tables will be created!**

# %%
# %sql
CREATE TABLE if not EXISTS git_analysis.bronze.customers
USING DELTA
AS
SELECT *
FROM read_files(
  '/Volumes/git_analysis/bronze/raw/raw_data/raw_customers.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE TABLE if not exists git_analysis.bronze.orderitems
USING DELTA
AS
SELECT *
FROM read_files(
  '/Volumes/git_analysis/bronze/raw/raw_data/raw_orderitems.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE TABLE if not exists git_analysis.bronze.orders
USING DELTA
AS
SELECT *
FROM read_files(
  '/Volumes/git_analysis/bronze/raw/raw_data/raw_orders.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE TABLE if not exists git_analysis.bronze.products
USING DELTA
AS
SELECT *
FROM read_files(
  '/Volumes/git_analysis/bronze/raw/raw_data/raw_products.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE TABLE if not exists git_analysis.bronze.reviews
USING DELTA
AS
SELECT *
FROM read_files(
  '/Volumes/git_analysis/bronze/raw/raw_data/raw_reviews.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

# %%
# %sql
CREATE TABLE if not exists git_analysis.bronze.transactions
USING DELTA
AS
SELECT *
FROM read_files(
  '/Volumes/git_analysis/bronze/raw/raw_data/raw_transactions.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);
