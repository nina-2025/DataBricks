# %%
#Used for:Revenue vs Rating scatter,Best-selling products,Low rating / high revenue detection

# %%
# %sql
CREATE OR REPLACE VIEW git_analysis.bi.vw_order_funnel AS
SELECT
    order_id,
    last_update_ts as order_last_updated,
    order_created_ts as order_date,
    final_status
FROM git_analysis.gold.gold_order_funnel
