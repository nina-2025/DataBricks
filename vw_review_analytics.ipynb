# %%
#Used for:Revenue vs Rating scatter,Best-selling products,Low rating / high revenue detection

# %%
# %sql
CREATE OR REPLACE VIEW git_analysis.bi.vw_review_analytics AS
SELECT
    product_id,
    review_count,
    avg_rating,
    last_review_date
FROM git_analysis.gold.gold_review_summary;
