# %%
#Used for:Executive dashboard,Revenue trends,Sales by region/category

# %%
# %sql
CREATE OR REPLACE VIEW git_analysis.bi.vw_customer_insights AS
SELECT
    customer_id,
    name,
    region,
    total_orders,
    total_revenue,
    avg_order_value,
    last_order_date
FROM git_analysis.gold.gold_customer_360;
