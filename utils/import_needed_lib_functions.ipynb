# %%
#This notebook is designed for reusability of libs and functions across different notebooks

# %%
# %python
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.sql.types import (
    StructType, StructField,
    IntegerType, StringType,DateType,TimestampType,DoubleType
)
from pyspark.sql.functions import col,lit, current_timestamp,current_date

spark.conf.set("spark.sql.session.timeZone", "UTC")
