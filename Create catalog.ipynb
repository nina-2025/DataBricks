# %% [markdown]
# This is git-integrated project for shop data analysis

# %%
# %sql
create catalog git_analysis

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS git_analysis.bronze;

# %%
# %sql
Create Schema if not exists git_analysis.silver;

# %%
# %sql
create schema if not exists git_analysis.gold;
