# %%
#Used for:Executive dashboard,Revenue trends,Sales by region/category

# %%
# %sql
CREATE OR REPLACE VIEW git_analysis.bi.vw_sales_dashboard AS
SELECT
    order_date,
    year,
    month,
    customer_region,
    product_category,
    revenue,
    quantity
FROM git_analysis.gold.gold_sales_fact;

# %%
# %sql
select * from git_analysis.bi.vw_sales_dashboard
